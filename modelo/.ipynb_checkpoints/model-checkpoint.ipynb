# %%
import tensorflow as tf
import os
import zipfile
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dense, Embedding, Bidirectional, LSTM, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop, Adamax, SGD, Nadam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, VGG19, Xception, InceptionV3, ResNet50, EfficientNetB4, InceptionResNetV2
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns



print(tf.__version__)
# Out:
# 2.8.0

# %% [markdown]
# ## 🧹 Dataset Preparation
#
# The dataset used in this project was composed of two separate CSV files, each with a different internal structure.
# To unify the data and prepare it for training, both files were read and processed using different approaches depending on their format.
#
# - One CSV file had a **structured format** with two labeled columns: `comentario (comment in English)` and `sentimiento (sentiment in English)`.
# - The second file required **manual parsing**, reading line by line and applying cleaning steps to extract usable comments.
#
# After processing, all the data was merged and loaded into a single **Pandas DataFrame** for further preprocessing and model training.

# %%
df1 = pd.read_csv("Comentarios2.csv", encoding="latin-1")

# %%
df1.head()
# Out:
#                         comentario sentimiento
# 0         Este producto me encantó    positivo
# 1       No cumplió lo que prometía    negativo
# 2            Me parece algo normal      neutro
# 3  Repetiría la compra sin dudarlo    positivo
# 4           El servicio fue pésimo    negativo

# %%
import pandas as pd

with open("Comentarios1.csv", "r", encoding="latin-1") as file:
    comments = [line.strip() for line in file if line.strip()]


for i in range(len(comments)):
    if '"' in comments[i]:
        comments[i] = comments[i].replace('""', "")
    comments[i] = comments[i].strip()

lista_comentarios = []
lista_sentimientos = []

for linea in comments:
    partes = linea.split(":")
    
    if len(partes) < 2:
        print("Línea con formato inesperado:", linea)
        continue

    comentario = partes[0].strip()
    sentimiento = partes[1].strip()

    lista_comentarios.append(comentario)
    lista_sentimientos.append(sentimiento)


df2 = pd.DataFrame()
df2["comentario"] = lista_comentarios
df2["sentimiento"] = lista_sentimientos
df2.sentimiento = df2.sentimiento.apply(lambda x : x.replace('"', "").strip())
df2.comentario = df2.comentario.apply(lambda x : x.replace('"', "").strip())
df2.head(100
)
# Out:
#                                            comentario sentimiento
# 0   Me encantó la rapidez de envío, llegó antes de...    positivo
# 1   La calidad del producto es buena, pero el prec...      neutro
# 2   No recomendaría este servicio, me ha dado much...    negativo
# 3   La atención al cliente fue excelente, resolvie...    positivo
# 4   El producto cumple su función, pero no supera ...      neutro
# ..                                                ...         ...
# 95  El producto me llegó usado y con signos de des...    negativo
# 96  La oferta no se ve mal, pero no incluye envío ...      neutro
# 97  Compré dos unidades y ambas funcionan de marav...    positivo
# 98  Tras varios intentos, sigue sin reconocer mi c...    negativo
# 99  La calidad del plástico es regular, no es ni m...      neutro
#
# [100 rows x 2 columns]

# %%
df= pd.concat([df1, df2], ignore_index = True)

# %% [markdown]
# ## 📊 Sentiment Distribution Analysis
#
# To ensure that the dataset is **balanced** across the three sentiment classes (*positive*, *neutral*, *negative*), we visualized the distribution of samples using two types of charts:
#
# - A **bar chart** to clearly compare the number of samples per class.
# - A **pie chart** to show the percentage representation of each sentiment.
#
# These visualizations confirmed that the dataset is well-balanced, which is important to help the model generalize properly and avoid bias toward any particular class.

# %%
df.describe(include = "all")
# Out:
#                       comentario sentimiento
# count                       2344        2344
# unique                      2007           3
# top     Este producto me encantó    positivo
# freq                          10         820

# %%
sentimientos = df.sentimiento.unique()

# %%
plt.pie(df.sentimiento.value_counts().values, labels=sentimientos, autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1a901659910>,
#   <matplotlib.patches.Wedge at 0x1a901666100>,
#   <matplotlib.patches.Wedge at 0x1a901666820>],
#  [Text(0.4999149384041554, 0.9798393002734529, 'positivo'),
#   Text(-1.093200842588509, -0.12211436346218435, 'negativo'),
#   Text(0.6055998948492084, -0.9182857765198305, 'neutro')],
#  [Text(0.27268087549317566, 0.534457800149156, '34.98%'),
#   Text(-0.5962913686846412, -0.06660783461573691, '33.58%'),
#   Text(0.3303272153722954, -0.5008831508289984, '31.44%')])

# %%
count_sentiments = df.groupby(["sentimiento"]).size().reset_index().rename(columns={0:"Sentiment Count"})
count_sentiments.head()
# Out:
#   sentimiento  Sentiment Count
# 0    negativo              787
# 1      neutro              737
# 2    positivo              820

# %%
sns.barplot(data = count_sentiments, x = "sentimiento", y = "Sentiment Count")
# Out:
# <AxesSubplot:xlabel='sentimiento', ylabel='Sentiment Count'>

# %% [markdown]
# ## 📊 Why This Split Matters
#
# It is very important that the **training set** represents the largest portion of the dataset, because this is the data the model actually learns from.
#
# The **validation set** is used during training to monitor how well the model is generalizing. It helps us detect problems like overfitting and adjust hyperparameters accordingly.
#
# Finally, the **test set** is used only once at the end of the training process — it gives us an unbiased estimate of the model’s real-world performance on unseen data.
#
# This split ensures that we can properly train, fine-tune, and evaluate our model with confidence.

# %%
#Dividir el conjunto de datos(train, validation, test)
from sklearn.model_selection import train_test_split

train_validation, test_df = train_test_split(df, test_size = 0.10, random_state = 42)
train_df, validation_df = train_test_split(train_validation, test_size = 0.15/(1-0.10), random_state = 42)

train_df = train_df.reset_index()
validation_df = validation_df.reset_index()
test_df = test_df.reset_index()

# %%
print("TOTAL TRAIN:",train_df.shape[0])
print("TOTAL VALIDATION:",validation_df.shape[0])
print("TOTAL TEST:",test_df.shape[0])
# Out:
# TOTAL TRAIN: 1757
# TOTAL VALIDATION: 352
# TOTAL TEST: 235

# %%
train_df.drop(columns = "index", inplace = True)
validation_df.drop(columns = "index", inplace = True)
test_df.drop(columns = "index", inplace = True)

# %%
train_df.head()
# Out:
#                                           comentario sentimiento
# 0  Nunca me llegó la confirmación de reserva, tuv...    negativo
# 1     El estado del producto superó mis expectativas    positivo
# 2   El tiempo de carga de la página web es excelente    positivo
# 3                Encontré varios defectos de fábrica    negativo
# 4  Fue un acierto total, me encanta la calidad y ...    positivo

# %% [markdown]
# ## 🧾 One-Hot Encoding of Sentiment Labels
#
# Since machine learning models cannot understand text labels directly, we apply **one-hot encoding** to convert the sentiment labels into a numerical format.
#
# This technique transforms each sentiment category (e.g., `positive`, `neutral`, `negative`) into a vector of binary values that the model can understand.
#
# For example:
# - `positive` → `[0, 0, 1]`
# - `neutral` → `[0, 1, 0]`
# - `negative` → `[1, 0, 0]`
#
# This step is essential for multi-class classification problems, as it allows the model to output probabilities for each class using functions like `softmax`.

# %%
#Codificación One-Hot de los conjuntos de entrenamiento/validación/prueba
train_df = pd.get_dummies(train_df, columns=["sentimiento"])
validation_df = pd.get_dummies(validation_df, columns=["sentimiento"])
test_df = pd.get_dummies(test_df, columns=["sentimiento"])

# %%
train_df.columns
# Out:
# Index(['comentario', 'sentimiento_negativo', 'sentimiento_neutro',
#        'sentimiento_positivo'],
#       dtype='object')

# %%
test_df.head()
# Out:
#                                           comentario  sentimiento_negativo  \
# 0  El software ofrece un rendimiento estable, aun...                 False
# 1  La calidad de la madera es fantástica, muy rec...                 False
# 2  La compra quedó registrada dos veces y el serv...                  True
# 3                    Repetiría la compra sin dudarlo                 False
# 4                          Nunca volveré a comprarlo                  True
#
#    sentimiento_neutro  sentimiento_positivo
# 0                True                 False
# 1               False                  True
# 2               False                 False
# 3               False                  True
# 4               False                 False

# %%
test_df[["sentimiento_negativo", 
                  "sentimiento_positivo", 
                  "sentimiento_neutro"]].values
# Out:
# array([[False, False,  True],
#        [False,  True, False],
#        [ True, False, False],
#        [False,  True, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False,  True, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False,  True, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False,  True, False],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False,  True, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [ True, False, False],
#        [False,  True, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False,  True, False],
#        [ True, False, False],
#        [False,  True, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False,  True, False],
#        [ True, False, False],
#        [False,  True, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        [False,  True, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False, False,  True],
#        [False,  True, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False,  True, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [ True, False, False],
#        [False,  True, False],
#        [ True, False, False],
#        [False,  True, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False, False,  True],
#        [False,  True, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False,  True, False],
#        [False,  True, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False,  True, False],
#        [False,  True, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False]])

# %%
y_train = train_df[["sentimiento_negativo", 
                    "sentimiento_neutro", 
                    "sentimiento_positivo"]].values
y_val = validation_df[["sentimiento_negativo", 
                       "sentimiento_neutro", 
                       "sentimiento_positivo"]].values
y_test = test_df[["sentimiento_negativo", 
                  "sentimiento_neutro", 
                  "sentimiento_positivo"]].values

# %% [markdown]
# ## 🔡 Text Tokenization and Padding
#
# Before feeding the text data into the neural network, we need to convert it into a numerical format that the model can understand.
#
# 1. We use a `Tokenizer` to build a vocabulary of the **5000 most frequent words** in the training set.
#    Each word is assigned a unique integer index, forming a dictionary.
#
# 2. The comments are then converted into sequences of integers, where each integer represents a word.
#    Words not in the top 5000 are replaced with a special token (`<OOV>`, Out-Of-Vocabulary).
#
# 3. Finally, we apply **padding** to ensure that all sequences have the same length (`maxlen = 50`).
#    This allows the input to be processed in batches and ensures consistency across training samples.
#
# This step is essential in NLP tasks to transform raw text into a **numerical** structured, model-ready format. **(Remember, the model only understands number!)**

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


tokenizer = Tokenizer(num_words=5000, oov_token='<OOV>')
tokenizer.fit_on_texts(train_df["comentario"])

train_sequences = tokenizer.texts_to_sequences(train_df["comentario"])
val_sequences = tokenizer.texts_to_sequences(validation_df["comentario"])
test_sequences = tokenizer.texts_to_sequences(test_df["comentario"])

max_length = 50
train_padded = pad_sequences(train_sequences, maxlen=max_length, padding='post', truncating='post')
val_padded = pad_sequences(val_sequences, maxlen=max_length, padding='post', truncating='post')
test_padded = pad_sequences(test_sequences, maxlen=max_length, padding='post', truncating='post')

# %%
X_train = train_padded
X_val = val_padded
X_test = test_padded

# %%
train_padded
# Out:
# array([[  52,    7,   29, ...,    0,    0,    0],
#        [   3,  232,   19, ...,    0,    0,    0],
#        [   3,   56,    4, ...,    0,    0,    0],
#        ...,
#        [ 150,    3,   74, ...,    0,    0,    0],
#        [  20,  340, 1946, ...,    0,    0,    0],
#        [  35,   55,  128, ...,    0,    0,    0]])

# %% [markdown]
# ## 💾 Saving the Tokenizer
#
# We save the `Tokenizer` object using Python's `pickle` module.
#
# This is very important because we'll need to use the **same tokenizer** later when we deploy the model in our Flask web app. If we used a new tokenizer, it could assign different indices to the words, leading to incorrect predictions.

# %%
import pickle

with open("modeltokenizer.pickle", "wb") as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
vocab_size = 5000          
embedding_dim = 128        
max_length = 50

# %% [markdown]
# ## 🧠 Model Definition
#
# The model is built using the **Sequential API** from Keras and consists of the following layers:
#
# 1. **Embedding Layer**
#    - Transforms each word index into a dense vector of fixed size.
#    - Helps the model learn relationships between words during training.
#    - Required because neural networks cannot understand raw integer indices.
#    - Defined as:
#      ```python
#      Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_length)
#      ```
#
# 2. **Bidirectional LSTM Layer**
#    - A Long Short-Term Memory (LSTM) layer that reads sequences in **both directions** (forward and backward).
#    - This allows the model to understand context from both past and future words.
#    - We use `return_sequences=False` to get a single output vector per comment.
#
# 3. **Dropout Layer**
#    - Randomly disables 50% of neurons during training to prevent overfitting.
#    - Helps the model generalize better, especially with small datasets.
#
# 4. **Dense Output Layer**
#    - Has 3 units (one for each sentiment class: positive, neutral, negative).
#    - Uses a **softmax** activation to output class probabilities.
#
# 5. **Compilation**
#    - Optimizer: `adam`, for efficient and adaptive learning.
#    - Loss: `categorical_crossentropy`, because we're using **one-hot encoded** labels.
#    - Metric: `accuracy` to evaluate how often the model predicts the correct class.
#
# ### 💡 Summary
# This architecture is designed for **multi-class text classification** and balances simplicity with performance. It includes essential layers for understanding text data, avoiding overfitting, and producing accurate class predictions.

# %% [markdown]
# ## 🧠 How Does the Embedding Layer Learn Word Meaning?
#
# At the beginning of training, the embedding layer assigns **random vectors** to each word.
# The model has no idea what words like *"happy"* or *"sad"* mean — it doesn't understand language like humans do.
#
# However, during training, the model sees many examples like:
#
# - "Estoy muy **feliz** con el producto" → `positive`
# - "Estoy muy **alegre** con el servicio" → `positive`
#
# Both *feliz* and *alegre* appear in **similar contexts** and lead to the **same sentiment label**.
#
# Over time:
# 1. The model makes predictions, compares them with the actual labels, and calculates the **error (loss)**.
# 2. Using backpropagation, it updates all trainable weights — including the vectors in the embedding layer.
# 3. It learns that making the vectors for *feliz* and *alegre* more similar helps it reduce the error.
# 4. As a result, their embeddings become **closer** in the vector space.
#
# This is how the model **learns the "meaning" of words through usage and context**, not by knowing their definitions.
#
# > ⚠️ Words that appear rarely may not have reliable embeddings, which is why we limit the vocabulary size and use `<OOV>` tokens.

# %%
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_length))

model.add(Bidirectional(LSTM(64, return_sequences=False)))

model.add(Dropout(0.5))

model.add(Dense(3, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 50, 128)           640000
#
#  bidirectional_6 (Bidirectio  (None, 128)              98816
#  nal)
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 739,203
# Trainable params: 739,203
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 🏋️ Model Training Begins
#
# We now begin training the model using the prepared training and validation data.
#
# The number of epochs has been set to a relatively high value (e.g., 100).
# This allows us to observe how the model behaves over time and helps us detect when **overfitting** begins to occur.
#
# By plotting the **training and validation accuracy/loss**, we can identify the point where the model stops improving on validation data while still improving on the training data. This is a typical sign of overfitting.
#
# You can use callbacks to stop the training process when it strarts to overfit the model

# %% [markdown]
# ## 🧪 Hyperparameter Tuning vs. Data Quantity
#
# To improve the model’s performance, we could experiment with different **hyperparameters**, such as:
#
# - `batch_size`
# - `learning_rate`
# - Number of LSTM units
# - Dropout rate
# - Optimizer choice
# - Embedding dimensions
#
# While adjusting these values may lead to better results, it's important to highlight that **one of the most critical factors in deep learning is the amount of training data**.
#
# With limited data, the model can struggle to generalize well — even if hyperparameters are carefully tuned.
# A larger dataset provides more variety, reduces noise, and gives the model more context to learn meaningful patterns, especially in tasks involving language and sentiment.
#
# > 🔑 **Conclusion**: Hyperparameter tuning is useful, but having **enough quality training data** is essential for achieving strong, reliable results.

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size
# Epoch 93/100
# 71/71 [==============================] - 2s 25ms/step - loss: 9.6646e-05 - accuracy: 1.0000 - val_loss: 1.2053 - val_accuracy: 0.8494
# Epoch 94/100
# 71/71 [==============================] - 2s 25ms/step - loss: 5.7222e-05 - accuracy: 1.0000 - val_loss: 1.2105 - val_accuracy: 0.8466
# Epoch 95/100
# 71/71 [==============================] - 2s 27ms/step - loss: 5.2146e-05 - accuracy: 1.0000 - val_loss: 1.2183 - val_accuracy: 0.8466
# Epoch 96/100
# 71/71 [==============================] - 2s 25ms/step - loss: 7.3499e-05 - accuracy: 1.0000 - val_loss: 1.2257 - val_accuracy: 0.8466
# Epoch 97/100
# 71/71 [==============================] - 2s 25ms/step - loss: 6.2914e-05 - accuracy: 1.0000 - val_loss: 1.2306 - val_accuracy: 0.8466
# Epoch 98/100
# 71/71 [==============================] - 2s 25ms/step - loss: 6.8030e-05 - accuracy: 1.0000 - val_loss: 1.2391 - val_accuracy: 0.8466
# Epoch 99/100
# 71/71 [==============================] - 2s 25ms/step - loss: 6.2454e-05 - accuracy: 1.0000 - val_loss: 1.2471 - val_accuracy: 0.8466
# Epoch 100/100
# 71/71 [==============================] - 2s 25ms/step - loss: 1.4227e-04 - accuracy: 1.0000 - val_loss: 1.2503 - val_accuracy: 0.8466

# %% [markdown]
# ## 📈 Training & Validation Metrics Visualization
#
# The plots below show the **accuracy** and **loss** for both the training and validation sets throughout the training process.
#
# ### 🔹 What do we observe?
#
# - In the **accuracy plot** (left), we can see that the training accuracy increases rapidly and reaches very high values, while the validation accuracy improves initially but eventually **plateaus** and slightly decreases.
#   This suggests that the model starts to **overfit** after a certain number of epochs.
#
# - In the **loss plot** (right), the training loss remains low, but the validation loss begins to increase — another strong sign of **overfitting**.
#
# ### 🔍 Why is this important?
#
# By training the model for many epochs, we can visualize the point at which the model stops generalizing well.
# This helps us identify the ideal number of training epochs or where to apply **EarlyStopping** to prevent overfitting in future runs.
#
# These visualizations are essential for evaluating model performance and guiding optimization decisions.

# %%
import matplotlib.pyplot as plt

# Obtener los datos del historial
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.figure(figsize=(32, 16))  

plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo-', label='Entrenamiento', markersize=10) 
plt.plot(epochs, val_acc, 'ro-', label='Validación', markersize=10) 
plt.title('Precisión durante el entrenamiento y la validación', fontsize=24)  
plt.xlabel('Épocas', fontsize=20) 
plt.ylabel('Precisión', fontsize=20)  
plt.legend(fontsize=18)  
plt.xticks(fontsize=16)  
plt.yticks(fontsize=16)  

# Graficar la pérdida en entrenamiento y validación
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo-', label='Entrenamiento', markersize=10)  
plt.plot(epochs, val_loss, 'ro-', label='Validación', markersize=10) 
plt.title('Pérdida durante el entrenamiento y la validación', fontsize=24)  
plt.xlabel('Épocas', fontsize=20) 
plt.ylabel('Pérdida', fontsize=20)  
plt.legend(fontsize=18) 
plt.xticks(fontsize=16)  
plt.yticks(fontsize=16)  

plt.tight_layout()  
plt.show()

# %% [markdown]
# ## ✅ Final Evaluation and Insights
#
# After evaluating the model on the test set, we obtained an accuracy of **83.4%**.
#
# This is a solid result considering that the model was trained with a relatively small dataset (~700 samples per class).
# As previously mentioned, having a **large and diverse dataset** is essential for allowing the model to **generalize well**. Even with a well-designed architecture and reasonable hyperparameters, limited training data can restrict the overall performance.
#
# One possible improvement would be to apply **Transfer Learning**, using a model that has already been trained on a large corpus of text for sentiment analysis or general language understanding. This approach would allow the model to start from a much richer understanding of language, which could significantly enhance its performance on this specific task.
#
# > 🎯 In real-world applications, combining a well-designed architecture with transfer learning and sufficient training data is often the key to achieving state-of-the-art results.

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=2)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 8/8 - 0s - loss: 1.2136 - accuracy: 0.8340 - 135ms/epoch - 17ms/step
# Test Loss: 1.213568091392517
# Test Accuracy: 0.8340425491333008

# %%
import numpy as np

loss, accuracy = model.evaluate(X_test, y_test, verbose=2)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)

predictions = model.predict(X_test)


predicted_indices = np.argmax(predictions, axis=1)


label_map = {
    0: "Negativo",
    1: "Neutro",
    2: "Positivo"
}

predicted_sentiments = [label_map[i] for i in predicted_indices]

for i in range(100):
    print("Comentario:", test_df.iloc[i]["comentario"])
    print("Sentimiento predicho:", predicted_sentiments[i])
    print("Probabilidades:", predictions[i])
    print("-" * 50)
# Out:
# 8/8 - 0s - loss: 1.2136 - accuracy: 0.8340 - 105ms/epoch - 13ms/step
# Test Loss: 1.213568091392517
# Test Accuracy: 0.8340425491333008
# Comentario: El software ofrece un rendimiento estable, aunque no sobresale en nada
# Sentimiento predicho: Neutro
# Probabilidades: [4.5879244e-08 1.0000000e+00 4.8167227e-08]
# --------------------------------------------------
# Comentario: La calidad de la madera es fantástica, muy recomendada
# Sentimiento predicho: Positivo
# Probabilidades: [1.38088545e-08 8.76174084e-08 9.99999881e-01]
# --------------------------------------------------
# Comentario: La compra quedó registrada dos veces y el servicio al cliente no me ayudó
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999869e-01 2.6414440e-07 1.0471173e-06]
# --------------------------------------------------
# Comentario: Repetiría la compra sin dudarlo
# Sentimiento predicho: Positivo
# Probabilidades: [6.886616e-09 5.963659e-08 9.999999e-01]
# --------------------------------------------------
# Comentario: Nunca volveré a comprarlo
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999797e-01 3.9668706e-07 1.6520655e-06]
# --------------------------------------------------
# Comentario: El servicio postventa es prácticamente inexistente
# Sentimiento predicho: Positivo
# Probabilidades: [2.1727365e-03 6.3674676e-04 9.9719054e-01]
# --------------------------------------------------
# Comentario: Lo mejor de todo fue la atención personalizada
# Sentimiento predicho: Positivo
# Probabilidades: [9.173047e-09 9.108110e-08 9.999999e-01]
# --------------------------------------------------
# Comentario: Es un servicio utilizable, aunque no es innovador
# Sentimiento predicho: Neutro
# Probabilidades: [7.7187717e-02 9.2223203e-01 5.8022229e-04]
# --------------------------------------------------
# Comentario: Nunca volveré a comprarlo
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999797e-01 3.9668706e-07 1.6520655e-06]
# --------------------------------------------------
# Comentario: En cuanto a tamaño, está dentro de lo estándar
# Sentimiento predicho: Neutro
# Probabilidades: [7.2457385e-07 9.9999797e-01 1.2638720e-06]
# --------------------------------------------------
# Comentario: El soporte telefónico se esforzó al máximo para asistirme
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999750e-01 6.9206055e-07 1.8051334e-06]
# --------------------------------------------------
# Comentario: Hubo un cargo adicional que no me explicaron claramente
# Sentimiento predicho: Negativo
# Probabilidades: [8.8163388e-01 1.1753722e-01 8.2891330e-04]
# --------------------------------------------------
# Comentario: El diseño simple facilita mucho su uso diario
# Sentimiento predicho: Neutro
# Probabilidades: [1.8164716e-06 9.9970430e-01 2.9392019e-04]
# --------------------------------------------------
# Comentario: El cupón de descuento se aplicó correctamente
# Sentimiento predicho: Negativo
# Probabilidades: [9.9996614e-01 1.5347354e-05 1.8418194e-05]
# --------------------------------------------------
# Comentario: El soporte técnico me pasó de un operador a otro sin resolver nada
# Sentimiento predicho: Negativo
# Probabilidades: [0.7872681  0.21006525 0.00266665]
# --------------------------------------------------
# Comentario: No noté ninguna mejora respecto a la versión gratuita
# Sentimiento predicho: Neutro
# Probabilidades: [1.6684451e-08 1.0000000e+00 3.2046657e-08]
# --------------------------------------------------
# Comentario: Los precios son demasiado altos para la calidad que ofrecen
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999547e-01 1.6606592e-06 2.8242380e-06]
# --------------------------------------------------
# Comentario: La descripción del artículo coincidía perfectamente con lo recibido
# Sentimiento predicho: Positivo
# Probabilidades: [3.2247019e-08 4.1091465e-07 9.9999952e-01]
# --------------------------------------------------
# Comentario: El empaque llegó todo golpeado y nadie se hizo responsable
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999893e-01 2.0667554e-07 8.8525974e-07]
# --------------------------------------------------
# Comentario: El restaurante se equivocó de orden y no quisieron reponerla
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999905e-01 2.7972004e-07 7.3227307e-07]
# --------------------------------------------------
# Comentario: Hasta el momento no he tenido inconvenientes
# Sentimiento predicho: Neutro
# Probabilidades: [4.088431e-06 9.999937e-01 2.228972e-06]
# --------------------------------------------------
# Comentario: El artículo estaba disponible en distintos tamaños
# Sentimiento predicho: Neutro
# Probabilidades: [5.9567952e-07 9.9999785e-01 1.5129381e-06]
# --------------------------------------------------
# Comentario: Me enviaron un artículo usado por error
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999976e-01 6.0215164e-08 1.3011277e-07]
# --------------------------------------------------
# Comentario: La calidad de sonido es impresionante, mucho mejor de lo que esperaba
# Sentimiento predicho: Positivo
# Probabilidades: [1.3465806e-09 1.9037241e-08 1.0000000e+00]
# --------------------------------------------------
# Comentario: El manual explica las funciones, aunque sea algo breve
# Sentimiento predicho: Neutro
# Probabilidades: [2.7704461e-08 1.0000000e+00 4.1754646e-08]
# --------------------------------------------------
# Comentario: El producto llegó con un defecto y no quisieron cambiarlo
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999952e-01 1.0015306e-07 3.4871945e-07]
# --------------------------------------------------
# Comentario: Me sentí estafado al ver la calidad real
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999976e-01 8.6090374e-08 1.1744713e-07]
# --------------------------------------------------
# Comentario: El empaque no tenía ningún diseño especial, pero cumplía su función
# Sentimiento predicho: Neutro
# Probabilidades: [5.97662861e-08 9.99999762e-01 1.06710665e-07]
# --------------------------------------------------
# Comentario: Todo se llevó a cabo de forma adecuada, sin inconvenientes
# Sentimiento predicho: Neutro
# Probabilidades: [8.1940811e-08 9.9999976e-01 1.1862616e-07]
# --------------------------------------------------
# Comentario: No hubo complicaciones, pero tampoco nada sobresaliente
# Sentimiento predicho: Neutro
# Probabilidades: [6.1593628e-09 1.0000000e+00 3.0486653e-08]
# --------------------------------------------------
# Comentario: El sistema se comporta de manera estable
# Sentimiento predicho: Positivo
# Probabilidades: [0.00240606 0.03418085 0.96341306]
# --------------------------------------------------
# Comentario: El servicio de posventa es uno de los mejores que he visto
# Sentimiento predicho: Positivo
# Probabilidades: [5.1726659e-08 3.2874527e-07 9.9999964e-01]
# --------------------------------------------------
# Comentario: Solicité soporte y me cerraron el chat sin previo aviso
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999797e-01 4.2807423e-07 1.5902795e-06]
# --------------------------------------------------
# Comentario: La presentación del producto es muy atractiva
# Sentimiento predicho: Positivo
# Probabilidades: [9.5447297e-07 6.7048182e-05 9.9993205e-01]
# --------------------------------------------------
# Comentario: No tengo comentarios específicos, todo parece en orden
# Sentimiento predicho: Neutro
# Probabilidades: [3.353493e-08 9.999999e-01 1.784239e-07]
# --------------------------------------------------
# Comentario: La falta de colores disponibles me decepcionó bastante
# Sentimiento predicho: Neutro
# Probabilidades: [3.0392353e-06 9.9997950e-01 1.7500688e-05]
# --------------------------------------------------
# Comentario: Los resultados fueron inmediatos y sorprendentes
# Sentimiento predicho: Positivo
# Probabilidades: [3.0246863e-06 3.7569812e-06 9.9999321e-01]
# --------------------------------------------------
# Comentario: La aplicación es fácil de usar y explica cada paso
# Sentimiento predicho: Positivo
# Probabilidades: [1.24735475e-08 1.30673357e-07 9.99999881e-01]
# --------------------------------------------------
# Comentario: El seguimiento del pedido no funcionó en ningún momento
# Sentimiento predicho: Negativo
# Probabilidades: [0.98781466 0.00132348 0.01086182]
# --------------------------------------------------
# Comentario: Ha sido muy complicado hablar con un representante
# Sentimiento predicho: Negativo
# Probabilidades: [0.9594912  0.02819772 0.01231109]
# --------------------------------------------------
# Comentario: Me encantó que incluyeran accesorios adicionales
# Sentimiento predicho: Positivo
# Probabilidades: [2.8714383e-05 2.2275164e-04 9.9974853e-01]
# --------------------------------------------------
# Comentario: La velocidad de carga del sitio fue adecuada durante todo el proceso
# Sentimiento predicho: Neutro
# Probabilidades: [3.7799676e-08 9.9999988e-01 1.7242964e-07]
# --------------------------------------------------
# Comentario: La factura llegó con un monto equivocado y fue un caos corregirlo
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999928e-01 1.9438832e-07 4.9195330e-07]
# --------------------------------------------------
# Comentario: La presentación del informe está bien
# Sentimiento predicho: Neutro
# Probabilidades: [2.4901989e-05 9.9995255e-01 2.2540196e-05]
# --------------------------------------------------
# Comentario: No trae características adicionales, pero hace lo que promete
# Sentimiento predicho: Neutro
# Probabilidades: [6.7973804e-09 9.9999988e-01 7.1388314e-08]
# --------------------------------------------------
# Comentario: Obtengo resultados rápidos y precisos, muy satisfecho
# Sentimiento predicho: Positivo
# Probabilidades: [2.5385051e-08 1.0650734e-07 9.9999988e-01]
# --------------------------------------------------
# Comentario: La entrega se extravió en algún punto y tuve que iniciar reclamos
# Sentimiento predicho: Negativo
# Probabilidades: [9.999738e-01 8.947567e-06 1.732506e-05]
# --------------------------------------------------
# Comentario: No noté diferencias entre este modelo y el anterior
# Sentimiento predicho: Neutro
# Probabilidades: [3.911040e-08 9.999902e-01 9.729015e-06]
# --------------------------------------------------
# Comentario: La atención fue muy mala
# Sentimiento predicho: Negativo
# Probabilidades: [9.99984145e-01 3.17741205e-06 1.26810155e-05]
# --------------------------------------------------
# Comentario: La velocidad de procesamiento es adecuada
# Sentimiento predicho: Neutro
# Probabilidades: [1.1333526e-06 9.9998295e-01 1.5895226e-05]
# --------------------------------------------------
# Comentario: Los asesores me brindaron un excelente seguimiento post-venta
# Sentimiento predicho: Positivo
# Probabilidades: [4.7298849e-09 3.9610697e-08 1.0000000e+00]
# --------------------------------------------------
# Comentario: El curso en línea fue excelente, aprendí muchísimo
# Sentimiento predicho: Positivo
# Probabilidades: [1.9343043e-08 1.3027369e-07 9.9999988e-01]
# --------------------------------------------------
# Comentario: La interfaz es un tanto anticuada
# Sentimiento predicho: Negativo
# Probabilidades: [0.6470731  0.32856348 0.02436345]
# --------------------------------------------------
# Comentario: Recibí un obsequio adicional que no esperaba
# Sentimiento predicho: Negativo
# Probabilidades: [0.9744562  0.02353157 0.00201224]
# --------------------------------------------------
# Comentario: La app es intuitiva al instalarla
# Sentimiento predicho: Negativo
# Probabilidades: [0.99581224 0.00100384 0.00318392]
# --------------------------------------------------
# Comentario: La descripción online es suficiente para entender las funciones
# Sentimiento predicho: Neutro
# Probabilidades: [3.4050689e-08 9.9999988e-01 1.7000991e-07]
# --------------------------------------------------
# Comentario: El acabado mate le da un toque discreto, me parece aceptable
# Sentimiento predicho: Neutro
# Probabilidades: [2.3762207e-07 9.9999917e-01 6.4008907e-07]
# --------------------------------------------------
# Comentario: La imagen publicada concuerda con la realidad, sin engaños
# Sentimiento predicho: Negativo
# Probabilidades: [0.99182546 0.00564508 0.0025294 ]
# --------------------------------------------------
# Comentario: El envío llegó en tiempo récord, no me lo esperaba
# Sentimiento predicho: Negativo
# Probabilidades: [0.81279165 0.01461899 0.17258932]
# --------------------------------------------------
# Comentario: Vale totalmente la pena
# Sentimiento predicho: Positivo
# Probabilidades: [1.8750285e-07 2.0472889e-07 9.9999964e-01]
# --------------------------------------------------
# Comentario: Se instaló sin problemas y el rendimiento es mejor de lo esperado
# Sentimiento predicho: Positivo
# Probabilidades: [1.5435127e-07 2.3552407e-06 9.9999750e-01]
# --------------------------------------------------
# Comentario: El cobro se realizó dos veces
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999952e-01 1.4226205e-07 3.2171903e-07]
# --------------------------------------------------
# Comentario: Es justo lo que necesitaba
# Sentimiento predicho: Neutro
# Probabilidades: [0.0127248 0.7895541 0.1977212]
# --------------------------------------------------
# Comentario: Este producto me encantó
# Sentimiento predicho: Positivo
# Probabilidades: [4.1283304e-08 1.2446912e-07 9.9999988e-01]
# --------------------------------------------------
# Comentario: El tamaño del empaque está bien ajustado al contenido
# Sentimiento predicho: Neutro
# Probabilidades: [1.1867364e-06 9.9999309e-01 5.7536568e-06]
# --------------------------------------------------
# Comentario: El repartidor fue muy descortés al momento de la entrega
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999487e-01 1.2045513e-06 3.9875354e-06]
# --------------------------------------------------
# Comentario: El artículo coincide completamente con la descripción del vendedor
# Sentimiento predicho: Neutro
# Probabilidades: [0.00259329 0.9897115  0.00769519]
# --------------------------------------------------
# Comentario: El empaque llegó deformado, aunque el contenido estaba bien
# Sentimiento predicho: Neutro
# Probabilidades: [4.4960455e-08 9.9999988e-01 1.6083311e-07]
# --------------------------------------------------
# Comentario: No cumplió lo que prometía
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999321e-01 4.3220816e-06 2.4588653e-06]
# --------------------------------------------------
# Comentario: El color no era exactamente como se veía en las fotos
# Sentimiento predicho: Neutro
# Probabilidades: [1.07290034e-04 9.99849081e-01 4.35871661e-05]
# --------------------------------------------------
# Comentario: La calidad de los adornos era mediana
# Sentimiento predicho: Positivo
# Probabilidades: [3.0299096e-05 4.0969526e-04 9.9955994e-01]
# --------------------------------------------------
# Comentario: La información estaba completa, aunque no sobresalía
# Sentimiento predicho: Neutro
# Probabilidades: [5.040339e-04 9.994868e-01 9.167009e-06]
# --------------------------------------------------
# Comentario: En general, cumple lo prometido, sin características adicionales
# Sentimiento predicho: Neutro
# Probabilidades: [4.4012786e-08 9.9999988e-01 9.4466699e-08]
# --------------------------------------------------
# Comentario: Es bastante neutral
# Sentimiento predicho: Neutro
# Probabilidades: [1.0055222e-06 9.9999487e-01 4.1761605e-06]
# --------------------------------------------------
# Comentario: El vendedor tardó demasiado en despachar el pedido
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999893e-01 2.0743241e-07 8.0603280e-07]
# --------------------------------------------------
# Comentario: El empaque no era muy vistoso, aunque protegió bien el producto
# Sentimiento predicho: Neutro
# Probabilidades: [1.7290438e-05 9.9682355e-01 3.1590573e-03]
# --------------------------------------------------
# Comentario: Tuvieron un error al enviar mi factura, aún no lo resuelven
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999988e-01 4.0179106e-08 8.4247013e-08]
# --------------------------------------------------
# Comentario: El color del producto coincide perfectamente con la descripción
# Sentimiento predicho: Positivo
# Probabilidades: [7.5286093e-06 1.1519404e-03 9.9884051e-01]
# --------------------------------------------------
# Comentario: Me resultó fácil navegar por la web y encontrar lo que necesitaba
# Sentimiento predicho: Positivo
# Probabilidades: [1.3274578e-08 6.1641600e-08 9.9999988e-01]
# --------------------------------------------------
# Comentario: Se equivocaron en el color y tardaron en aceptar el reclamo
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999928e-01 1.7887153e-07 5.1187646e-07]
# --------------------------------------------------
# Comentario: Nunca actualizaron el estado del envío
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999940e-01 1.5515617e-07 4.5934490e-07]
# --------------------------------------------------
# Comentario: La app se desconecta frecuentemente y pierde los datos
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999440e-01 8.9875414e-07 4.5957595e-06]
# --------------------------------------------------
# Comentario: No hay forma de cancelar la suscripción directamente
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999940e-01 2.3392117e-07 3.9704000e-07]
# --------------------------------------------------
# Comentario: No es compatible con mi dispositivo
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999845e-01 5.7556707e-07 9.1821380e-07]
# --------------------------------------------------
# Comentario: Las dimensiones son acordes a lo descrito en la página
# Sentimiento predicho: Neutro
# Probabilidades: [1.5282289e-05 9.9953449e-01 4.5024563e-04]
# --------------------------------------------------
# Comentario: No pude realizar mi compra debido a un fallo en el sistema
# Sentimiento predicho: Positivo
# Probabilidades: [1.1813283e-01 6.2850915e-04 8.8123870e-01]
# --------------------------------------------------
# Comentario: El manual vino incompleto
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999905e-01 3.5349305e-07 5.7671741e-07]
# --------------------------------------------------
# Comentario: El vendedor incluyó un detalle adicional que me encantó
# Sentimiento predicho: Positivo
# Probabilidades: [4.0099923e-09 4.0326903e-08 1.0000000e+00]
# --------------------------------------------------
# Comentario: La velocidad de procesamiento es decente
# Sentimiento predicho: Neutro
# Probabilidades: [0.00155107 0.8332069  0.165242  ]
# --------------------------------------------------
# Comentario: El producto parecía usado aunque lo vendían como nuevo
# Sentimiento predicho: Negativo
# Probabilidades: [0.9844951  0.01423864 0.00126627]
# --------------------------------------------------
# Comentario: Volvería a usar este servicio, quedé muy satisfecho
# Sentimiento predicho: Positivo
# Probabilidades: [1.1032923e-08 8.1824474e-08 9.9999988e-01]
# --------------------------------------------------
# Comentario: El empaque es genérico, pero protege bien el contenido
# Sentimiento predicho: Neutro
# Probabilidades: [9.5725250e-09 1.0000000e+00 5.3912025e-08]
# --------------------------------------------------
# Comentario: La velocidad de descarga es impresionante
# Sentimiento predicho: Positivo
# Probabilidades: [8.2959325e-08 7.0125196e-07 9.9999917e-01]
# --------------------------------------------------
# Comentario: Al querer cancelar la suscripción, me pusieron muchas trabas
# Sentimiento predicho: Negativo
# Probabilidades: [0.99218583 0.00246332 0.00535075]
# --------------------------------------------------
# Comentario: El empaque vino con manchas de humedad
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999285e-01 1.8315751e-06 5.3418839e-06]
# --------------------------------------------------
# Comentario: Fue un desperdicio de dinero
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999475e-01 1.7551974e-06 3.4644370e-06]
# --------------------------------------------------
# Comentario: Recibí un cupón de descuento muy generoso para mi próxima compra
# Sentimiento predicho: Positivo
# Probabilidades: [4.23623806e-06 1.12967955e-05 9.99984503e-01]
# --------------------------------------------------
# Comentario: El color y la textura son exactamente como se describe
# Sentimiento predicho: Neutro
# Probabilidades: [3.5511666e-06 9.9997389e-01 2.2498392e-05]
# --------------------------------------------------
# Comentario: Nunca volveré a comprarlo
# Sentimiento predicho: Negativo
# Probabilidades: [9.9999797e-01 3.9668706e-07 1.6520655e-06]
# --------------------------------------------------
# Comentario: La calidad del servicio al cliente es excelente
# Sentimiento predicho: Positivo
# Probabilidades: [7.9246647e-08 3.2722633e-07 9.9999964e-01]
# --------------------------------------------------

# %% [markdown]
# ## 💾 Saving the Model for Deployment
#
# After training and evaluating the model, we save it so that it can be reused in our **Flask web application**.
#
# This step is crucial because it allows us to deploy the model without retraining it every time.
# We also save the `Tokenizer` object, which is necessary to preprocess user input in the exact same way as during training.
#
# Both the model and the tokenizer will be loaded in the backend of the chatbot, allowing real-time sentiment predictions.
#
# ```python
# # Save the model
# model.save("best_model.h5")
#
# # Save the tokenizer
# with open("modeltokenizer.pickle", "wb") as handle:
#     pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
model.save("modelChatBot.h5")
